# %%
a=2
b=9
c="kiki"
d=4

# %%
p=c
c=4

# %%
print(c)
print(p)
# Out:
# kiki
# 4

# %%
a=6
b=2
asd=8

# %%
(a+b)/asd
print(h)
# Out:
# asd

# %%
h=asd
print(h)
# Out:
# 8

# %%
print('farooq')
# Out:
# farooq
