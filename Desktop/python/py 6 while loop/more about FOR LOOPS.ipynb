# %%
a = ['apple','banana','republic']

# %%
for element in a :
    print (element)
# Out:
# apple
# banana
# republic

# %%
# another way is by using the indices 
for i in range (0,3):#can also be written as range(3)
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range (3): # instead of using 3 we can also use len(a) (i,e. length of a)
    print(a[i])
# some times index matters rather as in second block
# Out:
# apple
# banana
# republic

# %%
# e.g. 
for i in range (3):
    for j in range (i + 1):
    # i=0 -> j=0
    # i=1-> j=0,1
    #i=2 -> j=0,1,2
        print(a[i])
# Out:
# apple
# banana
# banana
# republic
# republic
# republic
