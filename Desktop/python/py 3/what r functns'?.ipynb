# %%
# a collections of instructions
# a collections of code
# a nice things if function is we can use over n over again and again .....
def function1():
    print('aahh')
    print('aanj')
print('this is outside a function')
function1()
# Out:
# this is outside a function
# aahh
# aanj

# %%
function1()
# Out:
# aahh
# aanj

# %%
function1()
function1()
# Out:
# aahh
# aanj
# aahh
# aanj

# %%
# fn can be a mapping ie f of x
# input or an argument
# return value is assigned to assinged variablle n fn itself
def function2(x):
    print('hello')
    return 2*x

# %%
a = function2(3)
# Out:
# hello

# %%
print(a)
# Out:
# 6

# %%
b = function2(8)
print(b)
# Out:
# hello
# 16

# %%
def function2(x):
    print('hello')
    return 2*x
a = function2(3)
# Out:
# hello

# %%
def function2(x):
    print('hello')
    return 2*x
function2(3)
# Out:
# hello
# 6

# %%
def function2(x):
    print('hello')
    return 2*x
a = function2(3)
print(a)
# Out:
# hello
# 6

# %%
def function3(x,y):
    return (x**2)*(y**3)
e = function3(2,8)
print(e)
# Out:
# 2048

# %%
print(e)
# Out:
# 2048

# %%
def function4(x,y):
    return x*4+y*5
r = function4(2,2)

# %%
print(r)
# Out:
# 18

# %%
def f5(x,n,j):
    return x*n*j
q=f5(1,2,3)

# %%
print(q)
# Out:
# 6

# %%
# here is the application of swapping the variables also...
def f9(x,y):
    print(x,y)
    print('help')
    w=x
    x=y
    y=w
    print(x,y)
    return 3*x+4*y

# %%
f=f9(3,4)
# Out:
# 3 4
# help
# 4 3

# %%
print(f)
# Out:
# 24

# %%
f9(4,3)
# Out:
# 4 3
# help
# 3 4
# 25

# %%
def f0(x):
    print(x)
    print(34)
    return 2+x

# %%
f0(3)
# Out:
# 3
# 34
# 5

# %%
print(d)
# Out:
# 5

# %%
2+3
# Out:
# 5

# %%
def function3(x,y):
    print('aahh')
    print('aanj')
    return (x**2)*(y**3)
a=function3(2,8)
print(a)
# Out:
#   File "<ipython-input-11-7d75eec3601f>", line 4
#     return (x**2)*(y**3) and (2x)+(y)
#                                ^
# SyntaxError: invalid syntax

# %%
def function1():
    print('aahh')
    print('aanj')
print('this is outside a function')
function1()
function1()
# Out:
# this is outside a function
# aahh
# aanj
# aahh
# aanj

# %%
#here z can be replaced by any unknown alfabet or a sentence hence acting as f of x where x is variable similar 
#as of z here in tis case

def f3(z ):
    print(z )
    print('erty')
f3(1)
# Out:
# 1
# erty

# %%
# BMI CALCY
name1 = 'a'
ht1 = 2
wt1 = 90
name2 = 'b'
ht2 = 1.8
wt2 =70
name3 = 'c'
ht3 = 2.6
wt3 = 160

# %%
def bmi (name, ht, wt):
    bmi = wt / ht**2
    print("bmi")
    print(bmi)
    if bmi < 25 :
        return name + ' not overweight'
    else :
        return name + '  is over weight'

# %%
result1 = bmi(name1, ht1 , wt1)
result2 = bmi(name2, ht2 , wt2)
result3 = bmi(name3 , ht3, wt3)
# Out:
# bmi
# 22.5
# bmi
# 21.604938271604937
# bmi
# 23.668639053254434

# %%
print(result1)
print(result2)
print(result3)
# Out:
# a not overweight
# b not overweight
# c not overweight

# %%
# BMI CALCY
name1 = 'abdul'
ht1 = 2
wt1 = 90
name2 = 'baqar'
ht2 = 1.8
wt2 =70
name3 = 'calim'
ht3 = 2.6
wt3 = 160

def bmi (name, ht, wt):
    bmi = wt / ht**2
    print("bmi")
    print(bmi)
    if bmi < 25 :
        return name + ' not overweight'
    else :
        return name + '  is over weight'
bmi(name1, ht1 , wt1)
bmi(name2, ht2 , wt2)
bmi(name3 , ht3, wt3)
# Out:
# bmi
# 22.5
# bmi
# 21.604938271604937
# bmi
# 23.668639053254434
# 'calim not overweight'

# %%
# BMI CALCY
name = 'abdul'
ht = 1
wt = 90
name = 'baqar'
ht = 1.8
wt =70
name = 'calim'
ht = 1.6
wt = 160

def bmi (name, ht, wt):
    bmi = wt / ht**2
    print("bmi")
    print(bmi)
    if bmi < 25 :
        return name + ' not overweight'
    else :
        return name + '  is over weight'
bmi(name, ht , wt)
bmi(name, ht , wt)
bmi(name ,ht , wt)
# Out:
# bmi
# 62.499999999999986
# bmi
# 62.499999999999986
# bmi
# 62.499999999999986
# 'calim  is over weight'

# %%
# BMI CALCY
name1 = 'abdul'
ht1 = 1
wt1 = 90
name2 = 'baqar'
ht2 = 1.8
wt2 =70
name3 = 'calim'
ht3 = 2.6
wt3 = 160

def bmi (name, ht, wt):
    bmi = wt / ht**2
    print("bmi")
    print(bmi)
    if bmi < 25 :
        return name + ' not overweight'
    else :
        return name + '  is over weight'
result1 = bmi(name1, ht1 , wt1)
result2 = bmi(name2, ht2 , wt2)
result3 = bmi(name3 , ht3, wt3)
print(result1)
print(result2)
print(result3)
# Out:
# bmi
# 90.0
# bmi
# 21.604938271604937
# bmi
# 23.668639053254434
# abdul  is over weight
# baqar not overweight
# calim not overweight
