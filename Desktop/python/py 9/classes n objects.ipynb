# %%
class Robot :
    def __init__(self , name, color ,weight ):
        self.name = name 
        self.color = color 
        self.weight = weight
        
    def introduce_self (self):
        print ('My name is ' + self.name) # this in java

# %% [raw]
# r1

# %%
#r1 = Robot()
#r1.name ='tom'
#r1.color ='red'
#r1.weight = 30

#r2=Robot()
#r2.name='jerry'
#r2.color='blue'
#r2.weight=40
r1 = Robot('Tom','REd',30)
r2 = Robot('jerr','blue',40)

# %%
r1.introduce_self()
r2.introduce_self()
# Out:
# My name is Tom
# My name is jerr

# %%
class Robot:
    def __init__(self,N,C,W):
        self.name = N
        self.color = C
        self.weight = W
        
    def introduce_self (self):
        print ('My name is ' + self.name) # this in java

# %%
class person :
    def __init__(self, N, P , I):
        self.name = N
        self.personatility = P
        self.is_sitting = I
        
    def sit_down(self):
        self.
