# %%
a=0
b=1
if a<b:
    print('owais')
    print('plokijuhygtfrdeswaq')
print('owllw')
# Out:
# owais
# plokijuhygtfrdeswaq
# owllw

# %%
c=4
d=4
if c<d:
    print('c is less than d')
if c>d-1:
    print('lopk')
if c==d:
    print('opls')
# Out:
# lopk
# opls

# %%
e=9
f=9
if e<f:
    print('kkdkkdk')
if e+1>f:
    print('lr')
if e==f:
    print('kl')
# Out:
# lr
# kl

# %%
e=6
r=6
if e>r:
    print('kils')
else:
    if e<r:
        print('prt')
    else:
        print('oil')
# Out:
# oil

# %%
e=6
r=6
if e>r:
    print('kils')
elif e<r:
    print('prt')
else:
    print('oil')
# Out:
# oil

# %%
name='owais'
weight=100
height=2.0

bmi=(weight)/(height**2)+1
print('bmi:')
print(bmi)
if bmi<25:
    print(name)
    print('is not overweight')
else:    
    if bmi>25:
        print(name)
        print("is medium")
    else:
        print(name)
        print('is overweight')
# Out:
# bmi:
# 26.0
# owais
# is medium

# %%
a=8
b=7
if a<b:
    print('hyt')
if a>b:
    print('jkl')
if a==b:
    print('joke')
else:
    print('obo')
# Out:
# jkl
# obo

# %%
name='muzzu'
height=1.6
weight=67

bmi=weight/height**2
print('bmi:')
print(bmi)
if bmi<25:
    print(name)
    print('is not overweight')
else:
    if bmi>25:
        print(name)
        print('is very very overweight and motu')
    else:
        print(name)
        print('is overweight')
# Out:
# bmi:
# 26.171874999999996
# muzzu
# is very very overweight and motu

# %%
name='muzzu'
height=1.6
weight=67

bmi=weight/height**2
print('bmi:')
print(bmi)
if bmi<25:
    print(name)
    print('is not overweight')
elif bmi==25:
    print(name)
    print('is very very overweight and motu')
else:
    print( name + ' hello world' + ' 97')
    print('is overweight')
# Out:
# bmi:
# 26.171874999999996
# muzzu hello world 97
# is overweight

# %%
a=50
b=44
c=40
d=30
if a>b , a>c , a>d :
    print('oop')
if a>c:
    print('ool') 
if a>d:
    print('oon')
else :
    print('iio')
# Out:
#   File "<ipython-input-37-ebb75c7df7c8>", line 5
#     if a>b , a>c , a>d :
#            ^
# SyntaxError: invalid syntax

# %%
m=5
n=2
if m>n:
    print(9)
elif m<n:
    print(8)
else:
    print(4)
# Out:
# 9
