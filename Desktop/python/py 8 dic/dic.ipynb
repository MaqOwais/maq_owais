# %%
# this defines a new dic that's empty
d = {} # another way to write the same is d = dict {}
# can also use pre defined one as d = {'gorge': 23 , 'tme' : 12}

# %%
# adding the key value pair
d["gorge"] = 23 # this says add a new pair value where key is gorge  n value is 24

# %%
d['tom'] = 32
d['jammy'] = 12

# %%
print(d['gorge'])
# Out:
# 23
